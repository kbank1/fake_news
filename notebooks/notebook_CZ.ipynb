# %% [markdown]
# # Data

# %%
import os
import pandas as pd
import numpy as np

# Change to the correct directory
os.chdir('/Users/casparzizka/code/kbank1/fake_news')

# %%
# Load JSON files into DataFrames
hf_data = pd.read_json('raw_data/HF.json')
hr_data = pd.read_json('raw_data/HR.json')
mf_data = pd.read_json('raw_data/MF.json')
mr_data = pd.read_json('raw_data/MR.json')

# Display the first 5 rows of each DataFrame
print("HF Data - First 5 Rows:")
display(hf_data.head())

print("\nHR Data - First 5 Rows:")
display(hr_data.head())

print("\nMF Data - First 5 Rows:")
display(mf_data.head())

print("\nMR Data - First 5 Rows:")
display(mr_data.head())
# Out:
# HF Data - First 5 Rows:
#                                                           0     \
# id                                        gossipcop-1991455469
# text         ✕ Close Meghan Markle and Prince Harry have an...
# title        As it happened: Prince Harry and Meghan Markle...
# description         The wedding will take place in spring 2018
#
#                                                           1     \
# id                                        gossipcop-7798039260
# text         Kim Kardashian and Kanye West are pulling out ...
# title        Kim & Kanye Install At-Home Panic Room After P...
# description  'Keeping the kids safe is the couples number o...
#
#                                                           2     \
# id                                        gossipcop-7817725290
# text         Prince Harry and Meghan currently live at Kens...
# title        £1.4million spent renovating Prince Harry and ...
# ...

# %%
# Renaming the 'description' column to 'Title' and 'title' column to 'Description' in MR Data
mr_data.rename(columns={'description': 'Title', 'title': 'Description'}, inplace=True)

# Display the first 5 rows to confirm the changes
print("\nMR Data - Updated Column Names and First 5 Rows:")
display(mr_data.head())
# Out:
# MR Data - Updated Column Names and First 5 Rows:
#                                                           0     \
# id                                            gossipcop-951329
# description  Nothing says summer like watching a movie all ...
# text         With summer just around the corner, it's the p...
# title        11 Summer Camp Movies That'll Make You Nostalg...
#
#                                                           1     \
# id                                            gossipcop-861360
# description      What is Charrisse Jackson Jordan's net worth?
# text         Charrisse Jackson Jordan, an American reality ...
# title                       Charrisse Jackson Jordan Net Worth
#
#                                                           2     \
# id                                            gossipcop-911046
# description  The actor reveals why he decided to leave the ...
# text         Warning: This story contains major spoilers fr...
# ...

# %%
# Display the first 5 rows of each file
print("GossipCop Real - First 5 Rows:")
print(gossipcop_real.head(), "\n")

print("PolitiFact Fake - First 5 Rows:")
print(politifact_fake.head(), "\n")

print("GossipCop Fake - First 5 Rows:")
print(gossipcop_fake.head(), "\n")

print("PolitiFact Real - First 5 Rows:")
print(politifact_real.head(), "\n")
# Out:
# GossipCop Real - First 5 Rows:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Display the first 5 rows of each file
#       2 print("GossipCop Real - First 5 Rows:")
# ----> 3 print(gossipcop_real.head(), "\n")
#       5 print("PolitiFact Fake - First 5 Rows:")
#       6 print(politifact_fake.head(), "\n")
#
# NameError: name 'gossipcop_real' is not defined

# %%
print(hf_data.info())
print(hf_data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, id to description
# Columns: 4084 entries, 0 to 4083
# dtypes: object(4084)
# memory usage: 127.7+ KB
# None
#                         0                     1                     2     \
# count                      4                     4                     4
# unique                     4                     4                     4
# top     gossipcop-1991455469  gossipcop-7798039260  gossipcop-7817725290
# freq                       1                     1                     1
#
#                                                      3     \
# count                                                   4
# unique                                                  3
# top     Photos from Dancing With the Stars: Special Gu...
# freq                                                    2
#
#                         4                     5                     6     \
# ...

# %%
hf_data = hf_data.transpose()
hr_data = hr_data.transpose()
mf_data = mf_data.transpose()
mr_data = mr_data.transpose()

# %%
hf_data.columns = ['id', 'title', 'text', 'description']

# %%
print(hf_data.isnull().sum())
# Out:
# id             0
# title          0
# text           0
# description    0
# dtype: int64

# %%
print(hf_data.dtypes)
# Out:
# id             object
# title          object
# text           object
# description    object
# dtype: object

# %%
hf_data = hf_data.drop_duplicates()

# %%
print(hf_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4084 entries, 0 to 4083
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4084 non-null   object
#  1   title        4084 non-null   object
#  2   text         4084 non-null   object
#  3   description  4084 non-null   object
# dtypes: object(4)
# memory usage: 288.6+ KB
# None

# %%
hf_data = pd.read_json('raw_data/HF.json').transpose()
hr_data = pd.read_json('raw_data/HR.json').transpose()
mf_data = pd.read_json('raw_data/MF.json').transpose()
mr_data = pd.read_json('raw_data/MR.json').transpose()

# %%
hf_data.columns = ['id', 'title', 'text', 'description']
hr_data.columns = ['id', 'title', 'text', 'description']
mf_data.columns = ['id', 'title', 'text', 'description']
mr_data.columns = ['id', 'title', 'text', 'description']

# %%
hf_data.to_csv('cleaned_HF.csv', index=False)

# %%
hf_data['text_length'] = hf_data['text'].apply(len)
hf_data['title_length'] = hf_data['title'].apply(len)

hf_data['text_length'].hist()
hf_data['title_length'].hist()
# Out:
# <Axes: >

# %%
print(hf_data.dtypes)
# Out:
# id              object
# title           object
# text            object
# description     object
# text_length      int64
# title_length     int64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.hist(hf_data['text_length'], bins=20)
plt.title('Text Length Distribution')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %%
print("HF Data - First 5 Rows:")
display(hf_data.head())

print("\nHR Data - First 5 Rows:")
display(hr_data.head())

print("\nMF Data - First 5 Rows:")
display(mf_data.head())

print("\nMR Data - First 5 Rows:")
display(mr_data.head())
# Out:
# HF Data - First 5 Rows:
#                      id                                              title  \
# 0  gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1  gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2  gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3  gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4  gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
#
#                                                 text  \
# 0  As it happened: Prince Harry and Meghan Markle...
# 1  Kim & Kanye Install At-Home Panic Room After P...
# 2  £1.4million spent renovating Prince Harry and ...
# 3  Photos from Dancing With the Stars: Special Gu...
# 4  Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
#
#                                          description  text_length  \
# 0         The wedding will take place in spring 2018          113
# ...

# %%
# Renaming the 'description' column to 'Title' and 'title' column to 'Description' in MR Data
mr_data.rename(columns={'description': 'title', 'title': 'description'}, inplace=True)

# Display the first 5 rows to confirm the changes
print("\nMR Data - Updated Column Names and First 5 Rows:")
display(mr_data.head())
# Out:
# MR Data - Updated Column Names and First 5 Rows:
#                  id                                        description  \
# 0  gossipcop-951329  Nothing says summer like watching a movie all ...
# 1  gossipcop-861360      What is Charrisse Jackson Jordan's net worth?
# 2  gossipcop-911046  The actor reveals why he decided to leave the ...
# 3  gossipcop-899120  Pima County Office of the Medical Examiner con...
# 4  gossipcop-919455  Goop is kicking off its weekly podcast in a bi...
#
#                                                 text  \
# 0  With summer just around the corner, it's the p...
# 1  Charrisse Jackson Jordan, an American reality ...
# 2  Warning: This story contains major spoilers fr...
# 3  The Pima County Office of the Medical Examiner...
# 4  Goop is kicking off its weekly podcast in a bi...
#
#                                                title
# 0  11 Summer Camp Movies That'll Make You Nostalg...
# 1                 Charrisse Jackson Jordan Net Worth
# ...

# %%
# Reorder the columns to match HF, HR, and MF DataFrames
mr_data = mr_data[['id', 'title', 'text', 'description']]

# Display the first 5 rows to confirm the changes
print("\nMR Data - Reordered Columns and First 5 Rows:")
display(mr_data.head())
# Out:
# MR Data - Reordered Columns and First 5 Rows:
#                  id                                              title  \
# 0  gossipcop-951329  11 Summer Camp Movies That'll Make You Nostalg...
# 1  gossipcop-861360                 Charrisse Jackson Jordan Net Worth
# 2  gossipcop-911046  Raúl Esparza Exits Law & Order: SVU After Six ...
# 3  gossipcop-899120                 Lil Peep's Cause of Death Revealed
# 4  gossipcop-919455  Gwyneth Paltrow, Oprah Discuss Weinstein and #...
#
#                                                 text  \
# 0  With summer just around the corner, it's the p...
# 1  Charrisse Jackson Jordan, an American reality ...
# 2  Warning: This story contains major spoilers fr...
# 3  The Pima County Office of the Medical Examiner...
# 4  Goop is kicking off its weekly podcast in a bi...
#
#                                          description
# 0  Nothing says summer like watching a movie all ...
# 1      What is Charrisse Jackson Jordan's net worth?
# ...

# %%
print("HF Data - First 5 Rows:")
display(hf_data.head())

print("\nHR Data - First 5 Rows:")
display(hr_data.head())

print("\nMF Data - First 5 Rows:")
display(mf_data.head())

print("\nMR Data - First 5 Rows:")
display(mr_data.head())
# Out:
# HF Data - First 5 Rows:
#                      id                                              title  \
# 0  gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1  gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2  gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3  gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4  gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
#
#                                                 text  \
# 0  As it happened: Prince Harry and Meghan Markle...
# 1  Kim & Kanye Install At-Home Panic Room After P...
# 2  £1.4million spent renovating Prince Harry and ...
# 3  Photos from Dancing With the Stars: Special Gu...
# 4  Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
#
#                                          description  text_length  \
# 0         The wedding will take place in spring 2018          113
# ...

# %%
# !git add notebooks/notebook_CZ.ipynb
# !git commit -m "updated columns"
# !git push origin jupyter_data_caspar
# Out:
# [jupyter_data_caspar bdc4c7f] updated columns
#  1 file changed, 4 insertions(+), 1 deletion(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 445 bytes | 445.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To github.com:kbank1/fake_news.git
#    f33a9cd..bdc4c7f  jupyter_data_caspar -> jupyter_data_caspar

# %%
# Function to calculate text and title lengths
def add_length_columns(df):
    df['text_length'] = df['text'].apply(len)
    df['title_length'] = df['title'].apply(len)
    return df

# Apply to all DataFrames
hf_data = add_length_columns(hf_data)
hr_data = add_length_columns(hr_data)
mf_data = add_length_columns(mf_data)
mr_data = add_length_columns(mr_data)

# Display the first 5 rows of each DataFrame to confirm
print("HF Data - First 5 Rows with Length Columns:")
display(hf_data.head())

print("\nHR Data - First 5 Rows with Length Columns:")
display(hr_data.head())

print("\nMF Data - First 5 Rows with Length Columns:")
display(mf_data.head())

print("\nMR Data - First 5 Rows with Length Columns:")
display(mr_data.head())
# Out:
# HF Data - First 5 Rows with Length Columns:
#                      id                                               text  \
# 0  gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1  gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2  gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3  gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4  gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
#
#                                                title  \
# 0  As it happened: Prince Harry and Meghan Markle...
# 1  Kim & Kanye Install At-Home Panic Room After P...
# 2  £1.4million spent renovating Prince Harry and ...
# 3  Photos from Dancing With the Stars: Special Gu...
# 4  Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
#
#                                          description  text_length  \
# 0         The wedding will take place in spring 2018        15617
# ...

# %%
# I think 
def fix_column_labels(df):
    # Swap the text and title columns
    df = df.rename(columns={'text': 'temp_text', 'title': 'text'})
    df = df.rename(columns={'temp_text': 'title'})
    return df

# Apply the fix to HF, HR, and MF datasets
hf_data = fix_column_labels(hf_data)
hr_data = fix_column_labels(hr_data)
mf_data = fix_column_labels(mf_data)

# Display the updated DataFrames to confirm
print("HF Data - After Fixing Column Labels:")
display(hf_data.head())

print("\nHR Data - After Fixing Column Labels:")
display(hr_data.head())

print("\nMF Data - After Fixing Column Labels:")
display(mf_data.head())
# Out:
# HF Data - After Fixing Column Labels:
#                      id                                              title  \
# 0  gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1  gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2  gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3  gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4  gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
#
#                                                 text  \
# 0  As it happened: Prince Harry and Meghan Markle...
# 1  Kim & Kanye Install At-Home Panic Room After P...
# 2  £1.4million spent renovating Prince Harry and ...
# 3  Photos from Dancing With the Stars: Special Gu...
# 4  Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
#
#                                          description  text_length  \
# 0         The wedding will take place in spring 2018        15617
# ...

# %%
# Lets look at all tables again
print("HF Data - First 5 Rows with Length Columns:")
display(hf_data.head())

print("\nHR Data - First 5 Rows with Length Columns:")
display(hr_data.head())

print("\nMF Data - First 5 Rows with Length Columns:")
display(mf_data.head())

print("\nMR Data - First 5 Rows with Length Columns:")
display(mr_data.head())
# Out:
# HF Data - First 5 Rows with Length Columns:
#                      id                                              title  \
# 0  gossipcop-1991455469  ✕ Close Meghan Markle and Prince Harry have an...
# 1  gossipcop-7798039260  Kim Kardashian and Kanye West are pulling out ...
# 2  gossipcop-7817725290  Prince Harry and Meghan currently live at Kens...
# 3  gossipcop-5111151830  They can't get enough of the Biebs on this sho...
# 4  gossipcop-9658632569  Ben Affleck is keeping life with his three kid...
#
#                                                 text  \
# 0  As it happened: Prince Harry and Meghan Markle...
# 1  Kim & Kanye Install At-Home Panic Room After P...
# 2  £1.4million spent renovating Prince Harry and ...
# 3  Photos from Dancing With the Stars: Special Gu...
# 4  Jennifer Garner ‘Doesn’t Want’ Her Kids Around...
#
#                                          description  text_length  \
# 0         The wedding will take place in spring 2018        15617
# ...
